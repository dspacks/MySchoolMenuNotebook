# %% [markdown]
# <a href="https://colab.research.google.com/github/dspacks/MySchoolMenuNotebook/blob/main/school_menus_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # School Menu Calendar Generator
#
# **Simple approach:** Just paste the URL from your browser!
#
# ## How to Use
#
# 1. **Run the first cell** to install/import libraries
# 2. **Copy a menu URL from your browser** and paste it in "Step 1: Enter Menu URLs"
# 3. **Run remaining cells** to generate calendars
#
# ### Where to Find URLs
#
# 1. Visit your school menu website (e.g., healthepro.com or myschoolmenus.com)
# 2. Navigate to your school
# 3. Click on a menu (Breakfast, Lunch, etc.)
# 4. Copy the URL from your browser address bar
# 5. Paste it below!
#
# ### Example URLs
#
# - `https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948` (HealthePro)
# - `https://www.myschoolmenus.com/organizations/2230/sites/14066/menus/65638` (MySchoolMenus)

# %%
# Install required library
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)

# %%
# Import required modules
import requests
import json
import re
import uuid
import logging
from datetime import datetime, time, date, timedelta
from dataclasses import dataclass, field
from enum import Enum
from pathlib import Path
from typing import List, Dict, Optional

logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)

print("✓ Libraries imported")
# Out:
# ✓ Libraries imported

# %% [markdown]
# ## Helper Classes and Functions

# %%
def parse_menu_url(url: str) -> Dict[str, int]:
    """
    Extract district_id, site_id, menu_id from menu URL.

    Example:
        parse_menu_url("https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948")
        # Returns: {'district_id': 2230, 'site_id': 14066, 'menu_id': 102948}
    """
    url = url.strip()
    pattern = r'/organizations/(\d+)/sites/(\d+)/menus/(\d+)'
    match = re.search(pattern, url)

    if not match:
        raise ValueError(f"Could not parse URL: {url}")

    district_id, site_id, menu_id = match.groups()
    return {
        'district_id': int(district_id),
        'site_id': int(site_id),
        'menu_id': int(menu_id)
    }

# Test the parser
test_url = "https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948"
result = parse_menu_url(test_url)
print(f"✓ URL Parser Working")
print(f"  Example: {result}")
# Out:
# ✓ URL Parser Working
#   Example: {'district_id': 2230, 'site_id': 14066, 'menu_id': 102948}

# %%
class MenuType(Enum):
    BREAKFAST = "breakfast"
    LUNCH = "lunch"
    SNACK = "snack"
    DINNER = "dinner"

@dataclass
class MenuItem:
    date: date
    main_dish: str
    categories: List[str] = field(default_factory=list)
    all_items: List[str] = field(default_factory=list)
    menu_type: MenuType = MenuType.LUNCH

@dataclass
class CalendarEvent:
    summary: str
    dtstart: datetime | date
    uid: str = field(default_factory=lambda: str(uuid.uuid4()))
    dtstamp: datetime = field(default_factory=datetime.now)
    description: str = ""
    dtend: Optional[datetime] = None
    transp: str = "OPAQUE"

    def to_ical_lines(self) -> List[str]:
        def escape_text(text: str) -> str:
            text = text.replace("\\", "\\\\")
            text = text.replace(",", "\\,")
            text = text.replace(";", "\\;")
            text = text.replace("\n", "\\n")
            text = text.replace("\r", "\\r")
            return text

        def fold_line(property_name: str, content: str, max_length: int = 75) -> List[str]:
            first_line = f"{property_name}:{content}"
            if len(first_line) <= max_length:
                return [first_line]
            lines = []
            current_line = first_line
            while len(current_line) > max_length:
                lines.append(current_line[:max_length])
                current_line = " " + current_line[max_length:]
            if current_line:
                lines.append(current_line)
            return lines

        lines = [
            "BEGIN:VEVENT",
            f"SUMMARY:{escape_text(self.summary)}",
        ]

        if isinstance(self.dtstart, datetime):
            lines.append(f"DTSTART:{self.dtstart.strftime('%Y%m%dT%H%M%S')}")
        else:
            lines.append(f"DTSTART;VALUE=DATE:{self.dtstart.strftime('%Y%m%d')}")

        if self.dtend:
            lines.append(f"DTEND:{self.dtend.strftime('%Y%m%dT%H%M%S')}")

        lines.append(f"DTSTAMP:{self.dtstamp.strftime('%Y%m%dT%H%M%SZ')}")
        lines.append(f"UID:{self.uid}")

        if self.description:
            desc_lines = fold_line("DESCRIPTION", escape_text(self.description))
            lines.extend(desc_lines)

        lines.append(f"TRANSP:{self.transp}")
        lines.append("END:VEVENT")
        return lines

print("✓ Data classes defined")
# Out:
# ✓ Data classes defined

# %%
class MenuClient:
    """API client that fetches menus from HealthePro or MySchoolMenus."""

    def __init__(self):
        self.base_urls = [
            "https://menus.healthepro.com/api",
            "https://www.myschoolmenus.com/api",
            "https://myschoolmenus.com/api"
        ]

    def fetch_menu(self, url: str, menu_type: MenuType = MenuType.LUNCH) -> tuple[List[MenuItem], List[CalendarEvent]]:
        """Fetch menu items from URL.
        Returns a tuple of (menu_items, no_school_events).
        """
        ids = parse_menu_url(url)
        logger.info(f"Fetching: district {ids['district_id']}, site {ids['site_id']}, menu {ids['menu_id']} from {url}...")

        # Get current year and month for the new endpoint
        today = datetime.now()
        year = today.year
        month = today.month

        endpoint = f"/organizations/{ids['district_id']}/menus/{ids['menu_id']}/year/{year}/month/{month}/date_overwrites"

        data = None
        last_error = None
        for base_url in self.base_urls:
            try:
                full_url = f"{base_url}{endpoint}"
                logger.info(f"  Trying {full_url}")
                response = requests.get(full_url, timeout=10)
                response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)
                data = response.json()
                logger.info(f"  Successfully fetched data from {base_url}")
                logger.warning(f"  Raw API data received (first 500 chars): {str(data)[:500]}...")
                break
            except requests.exceptions.RequestException as e:
                last_error = e
                logger.warning(f"  Failed to fetch from {base_url}: {e}")
                continue
            except json.JSONDecodeError as e:
                last_error = e
                logger.warning(f"  Failed to decode JSON from {base_url}: {e}")
                continue
        else:
            raise Exception(f"Failed to fetch menu from all base URLs: {last_error}")

        if not data:
            logger.warning(f"  No data received for {url}")
            return [], [] # Return empty lists for both MenuItems and CalendarEvents

        raw_api_response = data
        actual_entries = []

        if isinstance(raw_api_response, dict) and 'data' in raw_api_response and isinstance(raw_api_response['data'], list):
            actual_entries = raw_api_response['data']
            logger.info("    Found daily items under 'data' key (list).")
        elif isinstance(raw_api_response, list):
            actual_entries = raw_api_response
            logger.info("    API response is a list of entries directly.")
        elif isinstance(raw_api_response, dict):
            if 'data' in raw_api_response:
                data_value = raw_api_response['data']
                if isinstance(data_value, dict):
                    if 'items' in data_value and isinstance(data_value['items'], list):
                        actual_entries = data_value['items']
                        logger.info("    Found daily items under 'data.items' key.")
                    elif 'days' in data_value and isinstance(data_value['days'], list):
                        actual_entries = data_value['days']
                        logger.info("    Found daily items under 'data.days' key.")
                    else:
                        logger.warning(f"    API response 'data' is a dictionary, but no 'items' or 'days' list found within it. Cannot extract daily menu entries. Raw data.data: {data_value}")
                else:
                    logger.warning(f"    Unexpected type for 'data' key value in API response ({type(data_value)}). Expected list or dictionary. Raw data.data: {data_value}")
            else:
                if 'items' in raw_api_response and isinstance(raw_api_response['items'], list):
                    actual_entries = raw_api_response['items']
                    logger.info("    Found daily items under 'items' key (top level).")
                elif 'days' in raw_api_response and isinstance(raw_api_response['days'], list):
                    actual_entries = raw_api_response['days']
                    logger.info("    Found daily items under 'days' key (top level).")
                else:
                    logger.warning(f"    API response is a dictionary, but no 'data', 'items', or 'days' list found at top level. Cannot extract daily menu entries. Raw data: {raw_api_response}")
        else:
            logger.warning(f"    Unexpected type for API response ({type(raw_api_response)}). Expected list or dictionary. Raw data: {raw_api_response}")

        items = []
        no_school_events = [] # Initialize list for 'no school' events

        logger.info(f"  Processing {len(actual_entries)} raw entries...")
        for entry in actual_entries:
            if entry is None:
                logger.debug("    Skipping None entry.")
                continue
            if not isinstance(entry, dict):
                logger.warning(f"    Skipping non-dictionary entry: {entry}")
                continue
            try:
                item_date = datetime.fromisoformat(entry['day']).date()
                setting = json.loads(entry.get('setting', '{}'))
                display_items = setting.get('current_display', [])

                main_dish = None
                categories = []
                all_items = []

                for item in display_items:
                    if item is None:
                        logger.debug("      Skipping None item in display_items.")
                        continue
                    item_name = item.get('name', 'Unknown')
                    item_type = item.get('type', 'unknown')
                    all_items.append(item_name)
                    if item_type == 'recipe' and main_dish is None:
                        main_dish = item_name
                    elif item_type == 'category':
                        categories.append(item_name)

                if main_dish:
                    items.append(MenuItem(
                        date=item_date,
                        main_dish=main_dish,
                        categories=categories,
                        all_items=all_items,
                        menu_type=menu_type
                    ))
                    logger.debug(f"    Added menu item: {main_dish} on {item_date}")
                else:
                    # Check for 'days_off' information if no main dish is found
                    days_off = setting.get('days_off')
                    if days_off and days_off.get('status') == 1:
                        description = days_off.get('description', 'No School')
                        no_school_event = CalendarEvent(
                            summary=description,
                            dtstart=item_date
                        )
                        no_school_events.append(no_school_event)
                        logger.info(f"    Added 'No School' event: {description} on {item_date}")
                    else:
                        logger.warning(f"    No main dish or valid 'days_off' found for entry on {item_date}. Raw entry: {entry}")
            except KeyError as e:
                logger.warning(f"    Skipping entry due to missing key ({e}): {entry}")
            except json.JSONDecodeError as e:
                logger.warning(f"    Skipping entry due to JSON decode error in setting: {e}, Raw setting: {entry.get('setting')}")
            except Exception as e:
                logger.warning(f"    Skipping entry due to unexpected error: {e}, Entry: {entry}")

        logger.info(f"✓ Retrieved {len(items)} menu items and {len(no_school_events)} 'no school' events for {url}")
        return items, no_school_events

print("✓ MenuClient class defined with corrected endpoint and improved data extraction")
# Out:
# ✓ MenuClient class defined with corrected endpoint and improved data extraction

# %%
class CalendarGenerator:
    """Generate RFC 5545-compliant iCalendar files."""

    def __init__(self, title: str = "School Menu Calendar"):
        self.title = title
        self.events = []

    def add_menu_item(self, item: MenuItem, event_time: Optional[time] = None) -> None:
        """Add menu item as calendar event."""
        prefix = item.menu_type.value[0].upper()
        summary = f"{prefix}: {item.main_dish}"

        description_parts = []
        for dish in item.all_items:
            if dish == dish.upper() or dish.endswith(':'):
                if description_parts:
                    description_parts.append("")
                description_parts.append(dish)
            else:
                description_parts.append(dish)

        description = "\n".join(description_parts)

        if event_time:
            dtstart = datetime.combine(item.date, event_time)
            duration = timedelta(minutes=30 if item.menu_type == MenuType.BREAKFAST else 45)
            dtend = dtstart + duration
        else:
            dtstart = item.date
            dtend = None

        event = CalendarEvent(
            summary=summary,
            dtstart=dtstart,
            dtend=dtend,
            description=description
        )
        self.events.append(event)

    def add_menu_items(self, items: List[MenuItem], event_time: Optional[time] = None) -> None:
        """Add multiple menu items."""
        for item in items:
            self.add_menu_item(item, event_time)

    def add_event(self, event: CalendarEvent) -> None:
        """Add a generic CalendarEvent object to the calendar."""
        self.events.append(event)

    def to_ics(self) -> str:
        """Generate iCalendar string."""
        lines = [
            "BEGIN:VCALENDAR",
            "VERSION:2.0",
            "PRODID:-//MenuAPI//EN",
            f"X-WR-CALNAME:{self.title}",
            "CALSCALE:GREGORIAN",
            "METHOD:PUBLISH"
        ]

        for event in self.events:
            lines.extend(event.to_ical_lines())

        lines.append("END:VCALENDAR")
        return "\r\n".join(lines)

    def save(self, filepath: str) -> None:
        """Save to .ics file."""
        Path(filepath).parent.mkdir(parents=True, exist_ok=True)
        with open(filepath, 'w', newline='') as f:
            f.write(self.to_ics())
        print(f"✓ Saved calendar to {filepath}")

print("✓ CalendarGenerator class defined")
# Out:
# ✓ CalendarGenerator class defined

# %% [markdown]
# ## Step 1: Enter Menu URLs
#
# Copy and paste your menu URLs below. You can have multiple URLs (breakfast, lunch, different schools, etc.)

# %%
#@title Enter Menu URLs
url_breakfast = "https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948" #@param {type:"string"}
url_lunch = "https://menus.healthepro.com/organizations/2230/sites/14066/menus/102946" #@param {type:"string"}

menu_urls = [url for url in [url_breakfast, url_lunch] if url]

if not menu_urls:
    print("⚠️  No URLs provided. Add menu URLs above and run again.")
else:
    print(f"✓ {len(menu_urls)} URL(s) configured")
    for i, url in enumerate(menu_urls, 1):
        try:
            ids = parse_menu_url(url)
            print(f"  {i}. District {ids['district_id']}, Menu {ids['menu_id']} ✓")
        except ValueError as e:
            print(f"  {i}. ERROR: {e}")
# Out:
# ✓ 2 URL(s) configured
#   1. District 2230, Menu 102948 ✓
#   2. District 2230, Menu 102946 ✓

# %% [markdown]
# ## Step 2: Configure Menu Types and Times
#
# For each URL, specify whether it's breakfast or lunch (determines event time in calendar).

# %%
# CONFIGURE MENU TYPES
# Format: (url, menu_type, event_time)
# menu_type: MenuType.BREAKFAST or MenuType.LUNCH
# event_time: time(hour, minute) or None for all-day events

#@title Configure Meal Times
breakfast_time_str = "08:00 AM" #@param {type:"string"}
lunch_time_str = "12:00 PM" #@param {type:"string"}

menu_configs = []

def parse_time_flexible(time_str: str, default_hour: int) -> time:
    """Attempts to parse time in multiple formats, or returns a default time if parsing fails."""
    formats_to_try = ['%H:%M', '%I:%M %p', '%I:%M%p'] # 24-hour, 12-hour with space, 12-hour without space
    for fmt in formats_to_try:
        try:
            return datetime.strptime(time_str, fmt).time()
        except ValueError:
            continue
    print(f"⚠️  Invalid time format: '{time_str}'. Please use 'HH:MM' (24-hour) or 'HH:MM AM/PM' (12-hour). Using default {default_hour:02d}:00.")
    return time(default_hour, 0)

# Get urls from global scope, safely handling cases where they might not be defined
current_url_breakfast = globals().get('url_breakfast')
current_url_lunch = globals().get('url_lunch')

# Parse times using the flexible function
breakfast_time = parse_time_flexible(breakfast_time_str, 8)
lunch_time = parse_time_flexible(lunch_time_str, 12)

# Debugging print statements (kept for consistency with previous step)
print(f"Debug: current_url_breakfast = {current_url_breakfast}")
print(f"Debug: current_url_lunch = {current_url_lunch}")

# Only add if the URL is not empty
if current_url_breakfast: # Non-empty string evaluates to True
    menu_configs.append((current_url_breakfast, MenuType.BREAKFAST, breakfast_time))
if current_url_lunch: # Non-empty string evaluates to True
    menu_configs.append((current_url_lunch, MenuType.LUNCH, lunch_time))

if not menu_configs:
    print("⚠️  No menu configurations. Add configs above or ensure URLs are set in the previous step.")
else:
    print(f"✓ {len(menu_configs)} menu configuration(s)")
    for i, (url, mtype, etime) in enumerate(menu_configs, 1):
        print(f"  {i}. {mtype.value.upper()} @ {etime}")
# Out:
# Debug: current_url_breakfast = https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948
# Debug: current_url_lunch = https://menus.healthepro.com/organizations/2230/sites/14066/menus/102946
# ✓ 2 menu configuration(s)
#   1. BREAKFAST @ 08:00:00
#   2. LUNCH @ 12:00:00

# %% [markdown]
# ## Step 3: Generate Calendars

# %%
client = MenuClient()
calendar = CalendarGenerator("School Menu Calendar")

all_fetched_items = [] # Store all fetched items for debugging/display

for url, menu_type, event_time in menu_configs:
    try:
        menu_items, no_school_events = client.fetch_menu(url, menu_type)
        all_fetched_items.extend(menu_items) # Add fetched menu items to the list
        calendar.add_menu_items(menu_items, event_time=event_time)

        # Add 'no school' events
        for event in no_school_events:
            calendar.add_event(event)

    except Exception as e:
        print(f"✗ Error processing {url}: {e}")

if calendar.events:
    print(f"\n✓ Total calendar events: {len(calendar.events)}")
else:
    print("⚠️  No calendar events generated")
# Out:
# WARNING:__main__:  Raw API data received (first 500 chars): {'data': [{'id': 1446771379, 'day': '2025-12-01', 'meal_id': 13909454, 'setting': '{"current_display":[{"item":"Breakfast Entree","weight":0,"name":"Breakfast Entree","type":"category"},{"item":1515512,"weight":1,"name":"Pull Apart Donut","type":"recipe"},{"item":1515500,"weight":2,"name":"Breakfast Bread Variety","type":"recipe"},{"item":"Fruit","weight":3,"name":"Fruit","type":"category"},{"item":1515426,"weight":4,"name":"Applesauce Cup Variety","type":"recipe"},{"item":1675059,"weight":5,"na...
# WARNING:__main__:  Raw API data received (first 500 chars): {'data': [{'id': 1446770897, 'day': '2025-12-01', 'meal_id': 13908972, 'setting': '{"current_display":[{"item":"Lunch Entree","weight":0,"name":"Lunch Entree","type":"category"},{"item":1652167,"weight":1,"name":"5\\" Deep Dish Turkey Pepperoni Pizza","type":"recipe"},{"item":1538143,"weight":2,"name":"5\\" Deep Dish Cheese Pizza","type":"recipe"},{"item":1598662,"weight":3,"name":"Yogurt\\/String Cheese\\/ Bread Meal","type":"recipe"},{"item":"Vegetables","weight":4,"name":"Vegetables","type":"...
# ✓ Total calendar events: 46

# %%
import pandas as pd

if all_fetched_items:
    print("--- Raw Fetched Menu Items ---")
    data = []
    for item in all_fetched_items:
        data.append({
            'Date': item.date,
            'Menu Type': item.menu_type.value.capitalize(),
            'Main Dish': item.main_dish,
            'Categories': ', '.join(item.categories),
            'All Items': ', '.join(item.all_items)
        })
    df_fetched = pd.DataFrame(data)
    # Set display options to avoid truncation for 'All Items'
    pd.set_option('display.max_colwidth', None)
    print(df_fetched.to_string(index=False))
    pd.reset_option('display.max_colwidth') # Reset to default
else:
    print("No raw menu items were fetched. This might indicate an issue with the URLs or the menu API.")
# Out:
# --- Raw Fetched Menu Items ---
#       Date Menu Type                                                  Main Dish                                                       Categories                                                                                                                                                                                                                                                                                                                                                                                                                  All Items
# 2025-12-01 Breakfast                                           Pull Apart Donut                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                 Breakfast Entree, Pull Apart Donut, Breakfast Bread Variety, Fruit, Applesauce Cup Variety, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-02 Breakfast                                             Frudel Variety                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                             Breakfast Entree, Frudel Variety, Breakfast Bread Variety, Fruit, Fresh Banana, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-03 Breakfast                                Egg Patty with Cheese slice                     Breakfast Entree, Fruit, Grains, Milk, Misc.                                                                                                                                                         Breakfast Entree, Egg Patty with Cheese slice, Chocolate & Chocolate Chip Muffin, Fruit, Apple Slices, Juice Box Variety, Grains, Split Top Biscuit, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-04 Breakfast                               Cinnamon & Sugar Mini Donuts                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                   Breakfast Entree, Cinnamon & Sugar Mini Donuts, Assorted Poptarts, Fruit, Fresh Orange, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-05 Breakfast                                Cherry Cocoa Soft Baked Bar                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                   Breakfast Entree, Cherry Cocoa Soft Baked Bar, Wild Blueberry Muffin, Fruit, Fresh Fruit, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-08 Breakfast                                         Cereal Bar Variety                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                           Breakfast Entree, Cereal Bar Variety, Muffin Variety, Fruit, Fruit Cup Variety, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-09 Breakfast                                       Turkey Sausage Patty                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                       Breakfast Entree, Turkey Sausage Patty, Breakfast Bread Variety, Fruit, Fresh Orange, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-10 Breakfast                                 Strawberry Nutri-Grain Bar                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                      Breakfast Entree, Strawberry Nutri-Grain Bar, Assorted Poptarts, Fruit, Fresh Apple, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-11 Breakfast                                        Colby Cheese Omelet                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                        Breakfast Entree, Colby Cheese Omelet, Breakfast Bread Variety, Fruit, Fresh Banana, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-12 Breakfast                                      Mini Chocolate Donuts                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                               Breakfast Entree, Mini Chocolate Donuts, Mini Powdered Sugar Donuts, Assorted Poptarts, Fruit, Fresh Fruit, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc.,
Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ketchup Packet, Mustard Packet, Ranch Dressing
# 2025-12-16     Lunch                                          Rotini Meat Sauce        Lunch Entree, Vegetables, Fruit, Grains, Milk, Condiments                                                                                             Lunch Entree, Rotini Meat Sauce, Grilled Cheese Sandwich, Parfait Lunch Meal with Granola, Vegetables, Steamed Green Beans, Carrot Sticks, Fruit, Diced Canned Pears,, Grains, Rotini Noodles, Garlic Knot, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ranch Dressing
# 2025-12-17     Lunch                       Stuffed Crust Turkey Pepperoni Pizza                Lunch Entree, Vegetables, Fruit, Milk, Condiments                                                                                                                  Lunch Entree, Stuffed Crust Turkey Pepperoni Pizza, Stuffed Crust Cheese Pizza, Yogurt/String Cheese/ Bread Meal, Vegetables, Buffalo Cauliflower, Tossed Salad, Fruit, Diced Peaches, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ranch Dressing
# 2025-12-18     Lunch                              Golden Crispy Chicken Tenders        Lunch Entree, Vegetables, Fruit, Grains, Milk, Condiments                      Lunch Entree, Golden Crispy Chicken Tenders, Hot & Spicy Chicken Tenders, Beef Hot Dog  on Bun, Yogurt/String Cheese/ Bread Meal, Vegetables, Edamame, Carrot Sticks, Fruit, Mixed Fruit Cocktail, Grains, Dutch Waffle, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ketchup Packet, Mustard Packet, Ranch Dressing, BBQ Sauce, Honey Mustard
# 2025-12-19     Lunch                                Pepperoni Cheesy Breadstick                Lunch Entree, Vegetables, Fruit, Milk, Condiments                                                                                                                                      Lunch Entree, Pepperoni Cheesy Breadstick, Cheesy Breadsticks, Yogurt/String Cheese/ Bread Meal, Vegetables, Corn, Carrot Sticks, Fruit, Mandarin Oranges, Canned, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ranch Dressing

# %% [markdown]
# ## Step 4: Save and Download

# %%
if calendar.events:
    output_file = "school_menu_calendar.ics"
    calendar.save(output_file)
    print(f"\n✓ Calendar saved: {output_file}")
    print(f"\nYou can now:")
    print(f"1. Download the .ics file from the left sidebar")
    print(f"2. Import into Google Calendar, Outlook, Apple Calendar, or any calendar app")
    print(f"3. Or open in your calendar application directly")
else:
    print("⚠️  No calendar to save. Check steps above for errors.")
# Out:
# ✓ Saved calendar to school_menu_calendar.ics
#
# ✓ Calendar saved: school_menu_calendar.ics
#
# You can now:
# 1. Download the .ics file from the left sidebar
# 2. Import into Google Calendar, Outlook, Apple Calendar, or any calendar app
# 3. Or open in your calendar application directly

# %% [markdown]
# ## Optional: View Calendar Data

# %%
import pandas as pd

if calendar.events:
    # Extract menu items from calendar
    data = []
    for event in calendar.events:
        data.append({
            'date': event.dtstart if isinstance(event.dtstart, date) else event.dtstart.date(),
            'menu': event.summary,
            'description_preview': event.description[:50] + '...' if len(event.description) > 50 else event.description
        })

    df = pd.DataFrame(data)
    print("Menu Calendar Preview:")
    print(df.to_string(index=False))

    # Save as CSV too
    df.to_csv('menu_data.csv', index=False)
    print("\n✓ Also saved menu data to menu_data.csv")
else:
    print("No calendar events to display")
# Out:
# Menu Calendar Preview:
#                date                                                          menu                                      description_preview
# 2025-12-01 08:00:00                                           B: Pull Apart Donut  Breakfast Entree\nPull Apart Donut\nBreakfast Bread ...
# 2025-12-02 08:00:00                                             B: Frudel Variety  Breakfast Entree\nFrudel Variety\nBreakfast Bread Va...
# 2025-12-03 08:00:00                                B: Egg Patty with Cheese slice  Breakfast Entree\nEgg Patty with Cheese slice\nChoco...
# 2025-12-11 12:00:00                               L: Breaded Chicken Patty w/ Bun  Lunch Entree\nBreaded Chicken Patty w/ Bun\nBeef Hot...
# 2025-12-12 12:00:00                                               L: Walking Taco Lunch Entree\nWalking Taco\nGrilled Cheese Sandwich\n...
# 2025-12-15 12:00:00                                            L: Pizza Crunchers Lunch Entree\nPizza Crunchers\nBeef Hot Dog  on Bun\n...
# 2025-12-16 12:00:00                                          L: Rotini Meat Sauce  Lunch Entree\nRotini Meat Sauce\nGrilled Cheese Sand...
# 2025-12-17 12:00:00                       L: Stuffed Crust Turkey Pepperoni Pizza  Lunch Entree\nStuffed Crust Turkey Pepperoni Pizza\n...
# 2025-12-18 12:00:00                              L: Golden Crispy Chicken Tenders  Lunch Entree\nGolden Crispy Chicken Tenders\nHot & S...
# 2025-12-19 12:00:00                                L: Pepperoni Cheesy Breadstick  Lunch Entree\nPepperoni Cheesy Breadstick\nCheesy Br...
#          2025-12-22                                      NO SCHOOL - WINTER BREAK
#          2025-12-23                                      NO SCHOOL - WINTER BREAK
#          2025-12-24                                      NO SCHOOL - WINTER BREAK
#          2025-12-25                                      NO SCHOOL - WINTER BREAK
#          2025-12-26                                      NO SCHOOL - WINTER BREAK
#          2025-12-29                                      NO SCHOOL - WINTER BREAK
#          2025-12-30                                      NO SCHOOL - WINTER BREAK
#          2025-12-31                                      NO SCHOOL - WINTER BREAK
#
# ✓ Also saved menu data to menu_data.csv

# %%
#@title Enter Menu URLs
url_breakfast = "https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948" #@param {type:"string"}
url_lunch = "https://menus.healthepro.com/organizations/2230/sites/14066/menus/102946" #@param {type:"string"}

menu_urls = [url for url in [url_breakfast, url_lunch] if url]

if not menu_urls:
    print("⚠️  No URLs provided. Add menu URLs above and run again.")
else:
    print(f"✓ {len(menu_urls)} URL(s) configured")
    for i, url in enumerate(menu_urls, 1):
        try:
            ids = parse_menu_url(url)
            print(f"  {i}. District {ids['district_id']}, Menu {ids['menu_id']} ✓")
        except ValueError as e:
            print(f"  {i}. ERROR: {e}")
# Out:
# ✓ 2 URL(s) configured
#   1. District 2230, Menu 102948 ✓
#   2. District 2230, Menu 102946 ✓

# %%
# CONFIGURE MENU TYPES
# Format: (url, menu_type, event_time)
# menu_type: MenuType.BREAKFAST or MenuType.LUNCH
# event_time: time(hour, minute) or None for all-day events

#@title Configure Meal Times
breakfast_time_str = "08:00 AM" #@param {type:"string"}
lunch_time_str = "12:00 PM" #@param {type:"string"}

menu_configs = []

def parse_time_flexible(time_str: str, default_hour: int) -> time:
    """Attempts to parse time in multiple formats, or returns a default time if parsing fails."""
    formats_to_try = ['%H:%M', '%I:%M %p', '%I:%M%p'] # 24-hour, 12-hour with space, 12-hour without space
    for fmt in formats_to_try:
        try:
            return datetime.strptime(time_str, fmt).time()
        except ValueError:
            continue
    print(f"⚠️  Invalid time format: '{time_str}'. Please use 'HH:MM' (24-hour) or 'HH:MM AM/PM' (12-hour). Using default {default_hour:02d}:00.")
    return time(default_hour, 0)

# Get urls from global scope, safely handling cases where they might not be defined
current_url_breakfast = globals().get('url_breakfast')
current_url_lunch = globals().get('url_lunch')

# Parse times using the flexible function
breakfast_time = parse_time_flexible(breakfast_time_str, 8)
lunch_time = parse_time_flexible(lunch_time_str, 12)

# Debugging print statements (kept for consistency with previous step)
print(f"Debug: current_url_breakfast = {current_url_breakfast}")
print(f"Debug: current_url_lunch = {current_url_lunch}")

# Only add if the URL is not empty
if current_url_breakfast: # Non-empty string evaluates to True
    menu_configs.append((current_url_breakfast, MenuType.BREAKFAST, breakfast_time))
if current_url_lunch: # Non-empty string evaluates to True
    menu_configs.append((current_url_lunch, MenuType.LUNCH, lunch_time))

if not menu_configs:
    print("⚠️  No menu configurations. Add configs above or ensure URLs are set in the previous step.")
else:
    print(f"✓ {len(menu_configs)} menu configuration(s)")
    for i, (url, mtype, etime) in enumerate(menu_configs, 1):
        print(f"  {i}. {mtype.value.upper()} @ {etime}")
# Out:
# Debug: current_url_breakfast = https://menus.healthepro.com/organizations/2230/sites/14066/menus/102948
# Debug: current_url_lunch = https://menus.healthepro.com/organizations/2230/sites/14066/menus/102946
# ✓ 2 menu configuration(s)
#   1. BREAKFAST @ 08:00:00
#   2. LUNCH @ 12:00:00

# %%
# GET THE DATA FROM THE ENDPOINTS

client = MenuClient()
calendar = CalendarGenerator("School Menu Calendar")

all_fetched_items = [] # Store all fetched items for debugging/display

for url, menu_type, event_time in menu_configs:
    try:
        items = client.fetch_menu(url, menu_type)
        all_fetched_items.extend(items) # Add fetched items to the list
        calendar.add_menu_items(items, event_time=event_time)
    except Exception as e:
        print(f"✗ Error processing {url}: {e}")

if calendar.events:
    print(f"\n✓ Total calendar events: {len(calendar.events)}")
else:
    print("⚠️  No calendar events generated")
# Out:
# WARNING:__main__:  Raw API data received (first 500 chars): {'data': [{'id': 1446771379, 'day': '2025-12-01', 'meal_id': 13909454, 'setting': '{"current_display":[{"item":"Breakfast Entree","weight":0,"name":"Breakfast Entree","type":"category"},{"item":1515512,"weight":1,"name":"Pull Apart Donut","type":"recipe"},{"item":1515500,"weight":2,"name":"Breakfast Bread Variety","type":"recipe"},{"item":"Fruit","weight":3,"name":"Fruit","type":"category"},{"item":1515426,"weight":4,"name":"Applesauce Cup Variety","type":"recipe"},{"item":1675059,"weight":5,"na...
# WARNING:__main__:    No main dish found for entry on 2025-12-22. Raw entry: {'id': 1446771394, 'day': '2025-12-22', 'meal_id': 13909469, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-23. Raw entry: {'id': 1446771395, 'day': '2025-12-23', 'meal_id': 13909470, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-24. Raw entry: {'id': 1446771396, 'day': '2025-12-24', 'meal_id': 13909471, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-25. Raw entry: {'id': 1446771397, 'day': '2025-12-25', 'meal_id': 13909472, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-26. Raw entry: {'id': 1446771398, 'day': '2025-12-26', 'meal_id': 13909473, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-29. Raw entry: {'id': 1446771399, 'day': '2025-12-29', 'meal_id': 13909474, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-30. Raw entry: {'id': 1446771400, 'day': '2025-12-30', 'meal_id': 13909475, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-31. Raw entry: {'id': 1446771401, 'day': '2025-12-31', 'meal_id': 13909476, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:  Raw API data received (first 500 chars): {'data': [{'id': 1446770897, 'day': '2025-12-01', 'meal_id': 13908972, 'setting': '{"current_display":[{"item":"Lunch Entree","weight":0,"name":"Lunch Entree","type":"category"},{"item":1652167,"weight":1,"name":"5\\" Deep Dish Turkey Pepperoni Pizza","type":"recipe"},{"item":1538143,"weight":2,"name":"5\\" Deep Dish Cheese Pizza","type":"recipe"},{"item":1598662,"weight":3,"name":"Yogurt\\/String Cheese\\/ Bread Meal","type":"recipe"},{"item":"Vegetables","weight":4,"name":"Vegetables","type":"...
# WARNING:__main__:    No main dish found for entry on 2025-12-22. Raw entry: {'id': 1446770912, 'day': '2025-12-22', 'meal_id': 13908987, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-23. Raw entry: {'id': 1446770913, 'day': '2025-12-23', 'meal_id': 13908988, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-24. Raw entry: {'id': 1446770914, 'day': '2025-12-24', 'meal_id': 13908989, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-25. Raw entry: {'id': 1446770915, 'day': '2025-12-25', 'meal_id': 13908990, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-26. Raw entry: {'id': 1446770916, 'day': '2025-12-26', 'meal_id': 13908991, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-29. Raw entry: {'id': 1446770917, 'day': '2025-12-29', 'meal_id': 13908992, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-30. Raw entry: {'id': 1446770918, 'day': '2025-12-30', 'meal_id': 13908993, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# WARNING:__main__:    No main dish found for entry on 2025-12-31. Raw entry: {'id': 1446770919, 'day': '2025-12-31', 'meal_id': 13908994, 'setting': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'setting_original': '{"current_display":[],"available_recipes":[],"hidden_items":[],"days_off":{"status":1,"description":"NO SCHOOL - WINTER BREAK"}}', 'overwritten': False}
# ✓ Total calendar events: 30

# %%
# Show Raw Menu Data
import pandas as pd

if all_fetched_items:
    print("--- Raw Fetched Menu Items ---")
    data = []
    for item in all_fetched_items:
        data.append({
            'Date': item.date,
            'Menu Type': item.menu_type.value.capitalize(),
            'Main Dish': item.main_dish,
            'Categories': ', '.join(item.categories),
            'All Items': ', '.join(item.all_items)
        })
    df_fetched = pd.DataFrame(data)
    # Set display options to avoid truncation for 'All Items'
    pd.set_option('display.max_colwidth', None)
    print(df_fetched.to_string(index=False))
    pd.reset_option('display.max_colwidth') # Reset to default
else:
    print("No raw menu items were fetched. This might indicate an issue with the URLs or the menu API.")
# Out:
# --- Raw Fetched Menu Items ---
#       Date Menu Type                                                  Main Dish                                                       Categories                                                                                                                                                                                                                                                                                                                                                                                                                  All Items
# 2025-12-01 Breakfast                                           Pull Apart Donut                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                 Breakfast Entree, Pull Apart Donut, Breakfast Bread Variety, Fruit, Applesauce Cup Variety, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-02 Breakfast                                             Frudel Variety                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                             Breakfast Entree, Frudel Variety, Breakfast Bread Variety, Fruit, Fresh Banana, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-03 Breakfast                                Egg Patty with Cheese slice                     Breakfast Entree, Fruit, Grains, Milk, Misc.                                                                                                                                                         Breakfast Entree, Egg Patty with Cheese slice, Chocolate & Chocolate Chip Muffin, Fruit, Apple Slices, Juice Box Variety, Grains, Split Top Biscuit, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-04 Breakfast                               Cinnamon & Sugar Mini Donuts                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                   Breakfast Entree, Cinnamon & Sugar Mini Donuts, Assorted Poptarts, Fruit, Fresh Orange, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-05 Breakfast                                Cherry Cocoa Soft Baked Bar                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                   Breakfast Entree, Cherry Cocoa Soft Baked Bar, Wild Blueberry Muffin, Fruit, Fresh Fruit, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-08 Breakfast                                         Cereal Bar Variety                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                           Breakfast Entree, Cereal Bar Variety, Muffin Variety, Fruit, Fruit Cup Variety, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-09 Breakfast                                       Turkey Sausage Patty                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                       Breakfast Entree, Turkey Sausage Patty, Breakfast Bread Variety, Fruit, Fresh Orange, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-10 Breakfast                                 Strawberry Nutri-Grain Bar                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                      Breakfast Entree, Strawberry Nutri-Grain Bar, Assorted Poptarts, Fruit, Fresh Apple, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-11 Breakfast                                        Colby Cheese Omelet                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                        Breakfast Entree, Colby Cheese Omelet, Breakfast Bread Variety, Fruit, Fresh Banana, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-12 Breakfast                                      Mini Chocolate Donuts                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                               Breakfast Entree, Mini Chocolate Donuts, Mini Powdered Sugar Donuts, Assorted Poptarts, Fruit, Fresh Fruit, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Yogurt Variety
# 2025-12-15 Breakfast                                              Oatmeal Round                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                                                                                                      Breakfast Entree, Oatmeal Round, Breakfast Bread Variety, Fruit, Craisins Variety, Juice Box Variety, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Misc., Cheese Stick
# 2025-12-16 Breakfast                                  ParfaitPro Vanilla Yogurt                     Breakfast Entree, Fruit, Grains, Milk, Misc.                                                                                                                                                                              Breakfast Entree, ParfaitPro Vanilla Yogurt, Assorted Poptarts, Fruit, Fresh Banana, Juice Box Variety, Grains, Cinnamon Granola, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Misc., Cheese Stick
# 2025-12-17 Breakfast                                   Cream Cheese Mini Bagels                             Breakfast Entree, Fruit, Milk, Misc.                                                                                                                                                
Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ranch Dressing
# 2025-12-18     Lunch                              Golden Crispy Chicken Tenders        Lunch Entree, Vegetables, Fruit, Grains, Milk, Condiments                      Lunch Entree, Golden Crispy Chicken Tenders, Hot & Spicy Chicken Tenders, Beef Hot Dog  on Bun, Yogurt/String Cheese/ Bread Meal, Vegetables, Edamame, Carrot Sticks, Fruit, Mixed Fruit Cocktail, Grains, Dutch Waffle, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ketchup Packet, Mustard Packet, Ranch Dressing, BBQ Sauce, Honey Mustard
# 2025-12-19     Lunch                                Pepperoni Cheesy Breadstick                Lunch Entree, Vegetables, Fruit, Milk, Condiments                                                                                                                                      Lunch Entree, Pepperoni Cheesy Breadstick, Cheesy Breadsticks, Yogurt/String Cheese/ Bread Meal, Vegetables, Corn, Carrot Sticks, Fruit, Mandarin Oranges, Canned, Milk, 1% White Milk - Borden, Strawberry Milk- FF  -Borden, Chocolate 1% Milk - Borden, Condiments, Ranch Dressing

# %% [markdown]
# ## Step 5: Auto Import to Google Calendar
#
# This section allows you to automatically import the generated menu events directly into your Google Calendar account.
#
# ### Setup Instructions
#
# 1. **First Time Setup**: You'll need to authenticate with Google
# 2. **Run the cells below** to install dependencies and upload to your calendar
# 3. **Grant permissions** when prompted
#
# The events will be uploaded to your primary Google Calendar.

# %%
# Install Google Calendar API library
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import os
import pickle

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/calendar']

def authenticate_google_calendar():
    """Authenticate with Google Calendar API."""
    creds = None
    
    # Token file stores the user's access and refresh tokens
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    
    # If there are no (valid) credentials available, let the user log in
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            # For Google Colab, use simplified authentication
            try:
                from google.colab import auth
                auth.authenticate_user()
                from google.auth import default
                creds, _ = default()
                print("✓ Authenticated via Google Colab")
            except ImportError:
                # For local/non-Colab environments, use OAuth flow
                print("⚠️  Note: You'll need OAuth credentials from Google Cloud Console")
                print("   Visit: https://console.cloud.google.com/apis/credentials")
                print("   Create OAuth 2.0 Client ID and download as 'credentials.json'")
                
                if not os.path.exists('credentials.json'):
                    print("✗ Error: credentials.json not found")
                    print("   Please follow instructions above to set up OAuth credentials")
                    return None
                
                flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
                creds = flow.run_local_server(port=0)
        
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
        print("✓ Authentication successful")
    
    return creds

def upload_events_to_google_calendar(calendar_obj, calendar_id='primary'):
    """
    Upload events from CalendarGenerator to Google Calendar.
    
    Args:
        calendar_obj: CalendarGenerator instance with events
        calendar_id: Google Calendar ID (default: 'primary' for main calendar)
    """
    creds = authenticate_google_calendar()
    if not creds:
        return
    
    try:
        service = build('calendar', 'v3', credentials=creds)
        
        print(f"\n📅 Uploading {len(calendar_obj.events)} events to Google Calendar...")
        
        uploaded_count = 0
        error_count = 0
        
        for event in calendar_obj.events:
            try:
                # Convert our CalendarEvent to Google Calendar event format
                google_event = {
                    'summary': event.summary,
                    'description': event.description,
                }
                
                # Handle date/datetime formatting
                if isinstance(event.dtstart, datetime):
                    google_event['start'] = {
                        'dateTime': event.dtstart.isoformat(),
                        'timeZone': 'America/New_York',  # Adjust timezone as needed
                    }
                    if event.dtend:
                        google_event['end'] = {
                            'dateTime': event.dtend.isoformat(),
                            'timeZone': 'America/New_York',
                        }
                    else:
                        # Default 1 hour duration if no end time
                        end_time = event.dtstart + timedelta(hours=1)
                        google_event['end'] = {
                            'dateTime': end_time.isoformat(),
                            'timeZone': 'America/New_York',
                        }
                else:
                    # All-day event
                    google_event['start'] = {
                        'date': event.dtstart.strftime('%Y-%m-%d'),
                    }
                    google_event['end'] = {
                        'date': event.dtstart.strftime('%Y-%m-%d'),
                    }
                
                # Upload to Google Calendar
                result = service.events().insert(calendarId=calendar_id, body=google_event).execute()
                uploaded_count += 1
                
            except HttpError as e:
                error_count += 1
                print(f"✗ Error uploading event '{event.summary}': {e}")
            except Exception as e:
                error_count += 1
                print(f"✗ Unexpected error uploading event '{event.summary}': {e}")
        
        print(f"\n✓ Upload complete!")
        print(f"  • Successfully uploaded: {uploaded_count} events")
        if error_count > 0:
            print(f"  • Errors: {error_count} events")
        
        # Provide link to view calendar
        print(f"\n🔗 View your calendar at: https://calendar.google.com")
        
    except HttpError as error:
        print(f'✗ An error occurred: {error}')
    except Exception as error:
        print(f'✗ Unexpected error: {error}')

print("✓ Google Calendar functions defined")

# %%
# Upload to Google Calendar
if calendar.events:
    print("Ready to upload events to Google Calendar!")
    print(f"Total events to upload: {len(calendar.events)}")
    print("\nRun this cell to start the upload process...")
    
    # Uncomment the line below to actually upload to Google Calendar
    # upload_events_to_google_calendar(calendar)
    
    print("\n⚠️  To enable automatic upload:")
    print("   1. Uncomment the line above (remove the #)")
    print("   2. Run this cell again")
    print("   3. Follow the authentication prompts")
else:
    print("⚠️  No events to upload. Generate calendar events first.")

# %% [markdown]
# ## Step 6: Visualize and Print Your Calendar
#
# Once you've generated your ICS file, you can use **Calendarify-AI** to create beautiful visual calendars perfect for printing!
#
# ### 🎨 Calendarify-AI - Calendar Visualization Tool
#
# **Calendarify-AI** combines Google's Gemini AI with calendar rendering to create stunning visualizations from your ICS files.
#
# #### 📱 Quick Access
#
# **Use the tool directly in Google AI Studio:**
# - [**Open Calendarify-AI in Google AI Studio**](https://ai.studio/apps/drive/1hO4RMt01FqIzeluJiFEniKD7fltlEdOG?fullscreenApplet=true)
#
# **View the source code on GitHub:**
# - [**Calendarify-AI GitHub Repository**](https://github.com/dspacks/Calendarify-AI/tree/main)
#
# #### 🖨️ How to Use for PDF Printing
#
# 1. **Download your ICS file** from Step 4 (school_menu_calendar.ics)
# 2. **Open Calendarify-AI** using the Google AI Studio link above
# 3. **Upload your ICS file(s)** to the visualization tool
# 4. **Generate the calendar view** with AI-enhanced visuals
# 5. **Print or export to PDF** directly from your browser (Ctrl+P / Cmd+P)
#
# #### ✨ Features
#
# - **Multiple ICS Support**: Upload multiple calendar files at once
# - **AI-Enhanced Visuals**: Uses Google Gemini for image generation
# - **Print-Ready**: Optimized layouts for physical printing
# - **Web-Based**: No installation required - runs directly in your browser
#
# ---
#
# **Tip:** The generated ICS file from this notebook is fully compatible with Calendarify-AI. Simply download it and upload to the visualization tool!
